# %%
#invite people for the Kaggle party
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('new_customers_update.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   gender                               715 non-null    int64
#  1   past_3_years_bike_related_purchases  715 non-null    int64
#  2   DOB                                  715 non-null    object
#  3   job_title                            715 non-null    object
#  4   job_industry_category                715 non-null    int64
#  5   wealth_segment                       715 non-null    int64
#  6   deceased_indicator                   715 non-null    object
#  7   owns_car                             715 non-null    int64
#  8   tenure                               715 non-null    int64
#  9   address                              715 non-null    object
#  10  postcode                             715 non-null    int64
# ...

# %%
df.head()
# Out:
#    gender  past_3_years_bike_related_purchases         DOB  \
# 0       1                                   86  1957-07-12
# 1       1                                   69  1970-03-22
# 2       0                                   10  1974-08-28
# 3       0                                   64  1979-01-28
# 4       0                                   34  1965-09-21
#
#                     job_title  job_industry_category  wealth_segment  \
# 0             General Manager                      5               2
# 1         Structural Engineer                      6               2
# 2      Senior Cost Accountant                      2               0
# 3  Account Representative III                      5               0
# 4           Financial Analyst                      2               0
#
#   deceased_indicator  owns_car  tenure              address  ...    country  \
# 0                  N         1      14     45 Shopko Center  ...  Australia
# ...

# %%
dob = df['DOB']

# %%
years = []

for i in dob:
    years.append(i[:4])

# %%
df['yob'] = years

# %%
df = df.drop(columns=['DOB'])

# %%
df['yob'] = df['yob'].astype('int')

# %%
decade = []

for index, row in df.iterrows():
    if (row["yob"] < 1950):
        decade.append('40')
    elif ((row["yob"] < 1960) and (row['yob'] > 1949)):
        decade.append('50')
    elif ((row["yob"] < 1970) and (row['yob'] > 1959)):
        decade.append('60')
    elif ((row["yob"] < 1980) and (row['yob'] > 1969)):
        decade.append('70')
    elif ((row["yob"] < 1990) and (row['yob'] > 1979)):
        decade.append('80')
    elif ((row["yob"] < 2000) and (row['yob'] > 1989)):
        decade.append('90')
    elif (row["yob"] > 1999):
        decade.append('00')
    else: 
        print(row['yob'])

# %%
df['decade'] = decade

# %%
df['decade'] = df['decade'].astype('int')

# %%
df.corr()
# Out:
#                                        gender  \
# gender                               1.000000
# past_3_years_bike_related_purchases  0.050769
# job_industry_category               -0.025675
# wealth_segment                      -0.028747
# owns_car                            -0.021761
# tenure                              -0.005018
# postcode                            -0.048064
# state                               -0.039533
# property_valuation                   0.017256
# Unnamed: 16                         -0.001666
# Unnamed: 17                         -0.011147
# Unnamed: 18                         -0.024077
# Unnamed: 19                         -0.026334
# Unnamed: 20                          0.037089
# Rank                                 0.037089
# Value                               -0.042810
# yob                                  0.038248
# decade                               0.026203
#
#                                      past_3_years_bike_related_purchases  \
# ...

# %%
corr = df.corr()
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
sns.heatmap(corr, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   gender                               715 non-null    int64
#  1   past_3_years_bike_related_purchases  715 non-null    int64
#  2   job_title                            715 non-null    object
#  3   job_industry_category                715 non-null    int64
#  4   wealth_segment                       715 non-null    int64
#  5   deceased_indicator                   715 non-null    object
#  6   owns_car                             715 non-null    int64
#  7   tenure                               715 non-null    int64
#  8   address                              715 non-null    object
#  9   postcode                             715 non-null    int64
#  10  state                                715 non-null    int64
# ...

# %%
# select numeric variables
numeric_vars =  ['gender', 'past_3_years_bike_related_purchases', 'job_industry_category',
                 'wealth_segment', 'owns_car', 
                 'tenure', 'postcode', 'state', 'property_valuation', 
                 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 
                 'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value', 'yob', 'decade']# create histograms for each numeric variable
fig = plt.figure(figsize=(24, 15))
for i in range(len(numeric_vars)):
    var = numeric_vars[i]
    sub = fig.add_subplot(5, 10, i + 1)
    sub.set_xlabel(var)
    df[var].plot(kind = 'hist')

# %%
df['decade'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['postcode'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['property_valuation'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['job_industry_category'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
