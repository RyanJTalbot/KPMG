# %%
#invite people for the Kaggle party
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('new_customers.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    object
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
#  11  address                              1000 non-null   object
#  12  postcode                             1000 non-null   int64
#  13  state                                1000 non-null   object
#  14  country                              1000 non-null   object
#  15  property_valuation                   1000 non-null   float64
#  16  Unnamed: 16                          1000 non-null   float64
#  17  Unnamed: 17                          1000 non-null   float64
#  18  Unnamed: 18                          1000 non-null   float64
#  19  Unnamed: 19                          1000 non-null   float64
#  20  Unnamed: 20                          1000 non-null   int64
#  21  Rank                                 1000 non-null   int64
#  22  Value                                1000 non-null   float64
# dtypes: float64(6), int64(5), object(12)
# memory usage: 179.8+ KB

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 715 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           715 non-null    object
#  1   last_name                            715 non-null    object
#  2   gender                               715 non-null    object
#  3   past_3_years_bike_related_purchases  715 non-null    int64
#  4   DOB                                  715 non-null    object
#  5   job_title                            715 non-null    object
#  6   job_industry_category                715 non-null    object
#  7   wealth_segment                       715 non-null    object
#  8   deceased_indicator                   715 non-null    object
#  9   owns_car                             715 non-null    object
#  10  tenure                               715 non-null    int64
#  11  address                              715 non-null    object
#  12  postcode                             715 non-null    int64
#  13  state                                715 non-null    object
#  14  country                              715 non-null    object
#  15  property_valuation                   715 non-null    float64
#  16  Unnamed: 16                          715 non-null    float64
#  17  Unnamed: 17                          715 non-null    float64
#  18  Unnamed: 18                          715 non-null    float64
#  19  Unnamed: 19                          715 non-null    float64
#  20  Unnamed: 20                          715 non-null    int64
#  21  Rank                                 715 non-null    int64
#  22  Value                                715 non-null    float64
# dtypes: float64(6), int64(5), object(12)
# memory usage: 134.1+ KB

# %%
df['name'] = df['first_name'] + " " + df['last_name']

# %%
df = df.drop(columns=['first_name', 'last_name'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 715 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   gender                               715 non-null    object
#  1   past_3_years_bike_related_purchases  715 non-null    int64
#  2   DOB                                  715 non-null    object
#  3   job_title                            715 non-null    object
#  4   job_industry_category                715 non-null    object
#  5   wealth_segment                       715 non-null    object
#  6   deceased_indicator                   715 non-null    object
#  7   owns_car                             715 non-null    object
#  8   tenure                               715 non-null    int64
#  9   address                              715 non-null    object
#  10  postcode                             715 non-null    int64
#  11  state                                715 non-null    object
#  12  country                              715 non-null    object
#  13  property_valuation                   715 non-null    float64
#  14  Unnamed: 16                          715 non-null    float64
#  15  Unnamed: 17                          715 non-null    float64
#  16  Unnamed: 18                          715 non-null    float64
#  17  Unnamed: 19                          715 non-null    float64
#  18  Unnamed: 20                          715 non-null    int64
#  19  Rank                                 715 non-null    int64
#  20  Value                                715 non-null    float64
#  21  name                                 715 non-null    object
# dtypes: float64(6), int64(5), object(11)
# memory usage: 128.5+ KB

# %%
df.nunique()
# Out:
# gender                                   2
# past_3_years_bike_related_purchases     99
# DOB                                    702
# job_title                              176
# job_industry_category                    9
# wealth_segment                           3
# deceased_indicator                       1
# owns_car                                 2
# tenure                                  22
# address                                715
# postcode                               435
# state                                    3
# country                                  1
# property_valuation                      12
# Unnamed: 16                             71
# Unnamed: 17                            127
# Unnamed: 18                            177
# Unnamed: 19                            292
# Unnamed: 20                            289
# Rank                                   289
# Value                                  284
# name                                   715
# dtype: int64

# %%
df["gender"] = df["gender"].astype("category").cat.codes

# %%
df["job_industry_category"] = df["job_industry_category"].astype("category").cat.codes

# %%
df["wealth_segment"] = df["wealth_segment"].astype("category").cat.codes

# %%
df["owns_car"] = df["owns_car"].astype("category").cat.codes

# %%
df["state"] = df["state"].astype("category").cat.codes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 715 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   gender                               715 non-null    int8
#  1   past_3_years_bike_related_purchases  715 non-null    int64
#  2   DOB                                  715 non-null    object
#  3   job_title                            715 non-null    object
#  4   job_industry_category                715 non-null    int8
#  5   wealth_segment                       715 non-null    int8
#  6   deceased_indicator                   715 non-null    object
#  7   owns_car                             715 non-null    int8
#  8   tenure                               715 non-null    int64
#  9   address                              715 non-null    object
#  10  postcode                             715 non-null    int64
#  11  state                                715 non-null    int8
#  12  country                              715 non-null    object
#  13  property_valuation                   715 non-null    float64
#  14  Unnamed: 16                          715 non-null    float64
#  15  Unnamed: 17                          715 non-null    float64
#  16  Unnamed: 18                          715 non-null    float64
#  17  Unnamed: 19                          715 non-null    float64
#  18  Unnamed: 20                          715 non-null    int64
#  19  Rank                                 715 non-null    int64
#  20  Value                                715 non-null    float64
#  21  name                                 715 non-null    object
# dtypes: float64(6), int64(5), int8(5), object(6)
# memory usage: 104.0+ KB

# %%
corr = df.corr()
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
sns.heatmap(corr, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
df.size
# Out:
# 15730

# %%
df = df.drop_duplicates()

# %%
df.size
# Out:
# 15730
