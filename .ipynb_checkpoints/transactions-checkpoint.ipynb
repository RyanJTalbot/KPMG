# %%
#invite people for the Kaggle party
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
transactions = pd.read_csv('transactions.csv')

# %%
transactions
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950          2/25/17        False
# 1                   2           3         3120          5/21/17         True
# 2                   3          37          402         10/16/17        False
# 3                   4          88         3135          8/31/17        False
# 4                   5          78          787          10/1/17         True
# ...               ...         ...          ...              ...          ...
# 19995           19996          51         1018          6/24/17         True
# 19996           19997          41          127          11/9/17         True
# 19997           19998          87         2284          4/14/17         True
# 19998           19999           6         2764           7/3/17        False
# 19999           20000          11         1144          9/22/17         True
#
#       order_status           brand product_line product_class product_size  \
# 0         Approved           Solex     Standard        medium       medium
# 1         Approved   Trek Bicycles     Standard        medium        large
# 2         Approved      OHM Cycles     Standard           low       medium
# 3         Approved  Norco Bicycles     Standard        medium       medium
# 4         Approved  Giant Bicycles     Standard        medium        large
# ...            ...             ...          ...           ...          ...
# 19995     Approved      OHM Cycles     Standard          high       medium
# 19996     Approved           Solex         Road        medium       medium
# 19997     Approved      OHM Cycles     Standard        medium       medium
# 19998     Approved      OHM Cycles     Standard          high       medium
# 19999     Approved   Trek Bicycles     Standard        medium        small
#
#        list_price standard_cost  product_first_sold_date
# 0           71.49        $53.62                  41245.0
# 1         2091.47       $388.92                  41701.0
# 2         1793.43       $248.82                  36361.0
# 3         1198.46       $381.10                  36145.0
# 4         1765.30       $709.48                  42226.0
# ...           ...           ...                      ...
# 19995     2005.66     $1,203.40                  37823.0
# 19996      416.98       $312.74                  35560.0
# 19997     1636.90        $44.71                  40410.0
# 19998      227.88       $136.73                  38216.0
# 19999     1775.81     $1,580.47                  36334.0
#
# [20000 rows x 13 columns]

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  object
#  4   online_order             19640 non-null  object
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  object
#  12  product_first_sold_date  19803 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 2.0+ MB

# %%
transactions.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
transactions.describe()
# Out:
#        transaction_id   product_id   customer_id    list_price  \
# count    20000.000000  20000.00000  20000.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050   1107.829449
# std       5773.647028     30.75359   1011.951046    582.825242
# min          1.000000      0.00000      1.000000     12.010000
# 25%       5000.750000     18.00000    857.750000    575.270000
# 50%      10000.500000     44.00000   1736.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000   1635.300000
# max      20000.000000    100.00000   5034.000000   2091.470000
#
#        product_first_sold_date
# count             19803.000000
# mean              38199.776549
# std                2875.201110
# min               33259.000000
# 25%               35667.000000
# 50%               38216.000000
# 75%               40672.000000
# max               42710.000000

# %%
transactions.corr()
# Out:
#                          transaction_id  product_id  customer_id  list_price  \
# transaction_id                 1.000000   -0.011486     0.001753   -0.006154
# product_id                    -0.011486    1.000000     0.004278    0.090066
# customer_id                    0.001753    0.004278     1.000000    0.009306
# list_price                    -0.006154    0.090066     0.009306    1.000000
# product_first_sold_date        0.004835   -0.052961    -0.001521    0.059367
#
#                          product_first_sold_date
# transaction_id                          0.004835
# product_id                             -0.052961
# customer_id                            -0.001521
# list_price                              0.059367
# product_first_sold_date                 1.000000

# %%
transactions.cov()
# Out:
#                          transaction_id   product_id   customer_id  \
# transaction_id             3.333500e+07 -2039.455748  1.024228e+04
# product_id                -2.039456e+03   945.783270  1.331277e+02
# customer_id                1.024228e+04   133.127684  1.024045e+06
# list_price                -2.070871e+04  1614.346379  5.488308e+03
# product_first_sold_date    8.029532e+04 -4654.962856 -4.424897e+03
#
#                             list_price  product_first_sold_date
# transaction_id           -20708.712943             8.029532e+04
# product_id                 1614.346379            -4.654963e+03
# customer_id                5488.308117            -4.424897e+03
# list_price               339685.263157             9.947400e+04
# product_first_sold_date   99474.003051             8.266781e+06

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  object
#  4   online_order             19640 non-null  object
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  object
#  12  product_first_sold_date  19803 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 2.0+ MB

# %%
transactions['online_order'].value_counts()
# Out:
# True     9829
# False    9811
# Name: online_order, dtype: int64

# %%
transactions['order_status'].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
transactions['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
transactions['product_line'].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %%
transactions['product_class'].value_counts()
# Out:
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64

# %%
transactions['product_size'].value_counts()
# Out:
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64

# %%
transactions['customer_id'].value_counts()
# Out:
# 2183    14
# 2476    14
# 1068    14
# 1672    13
# 2912    13
#         ..
# 898      1
# 2352     1
# 1846     1
# 3279     1
# 1757     1
# Name: customer_id, Length: 3494, dtype: int64

# %%
transactions.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
df = transactions.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19445 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           19445 non-null  int64
#  1   product_id               19445 non-null  int64
#  2   customer_id              19445 non-null  int64
#  3   transaction_date         19445 non-null  object
#  4   online_order             19445 non-null  object
#  5   order_status             19445 non-null  object
#  6   brand                    19445 non-null  object
#  7   product_line             19445 non-null  object
#  8   product_class            19445 non-null  object
#  9   product_size             19445 non-null  object
#  10  list_price               19445 non-null  float64
#  11  standard_cost            19445 non-null  object
#  12  product_first_sold_date  19445 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 2.1+ MB

# %%
df.cov()
# Out:
#                          transaction_id   product_id   customer_id  \
# transaction_id             3.340457e+07 -2055.547041  1.625202e+04
# product_id                -2.055547e+03   934.646961  1.042161e+02
# customer_id                1.625202e+04   104.216095  1.023920e+06
# list_price                -2.152136e+04  1604.691334  6.880889e+03
# product_first_sold_date    7.304393e+04 -4764.973731 -6.714560e+03
#
#                             list_price  product_first_sold_date
# transaction_id           -21521.358889             7.304393e+04
# product_id                 1604.691334            -4.764974e+03
# customer_id                6880.888749            -6.714560e+03
# list_price               339495.471923             9.921499e+04
# product_first_sold_date   99214.987844             8.283275e+06

# %%
df.corr()
# Out:
#                          transaction_id  product_id  customer_id  list_price  \
# transaction_id                 1.000000   -0.011633     0.002779   -0.006391
# product_id                    -0.011633    1.000000     0.003369    0.090085
# customer_id                    0.002779    0.003369     1.000000    0.011671
# list_price                    -0.006391    0.090085     0.011671    1.000000
# product_first_sold_date        0.004391   -0.054155    -0.002306    0.059164
#
#                          product_first_sold_date
# transaction_id                          0.004391
# product_id                             -0.054155
# customer_id                            -0.002306
# list_price                              0.059164
# product_first_sold_date                 1.000000

# %%
# data for
# online_order
# order_status
# brand
# product_line
# product_class
# product_size

# %%
df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950          2/25/17        False
# 1               2           3         3120          5/21/17         True
# 2               3          37          402         10/16/17        False
# 3               4          88         3135          8/31/17        False
# 4               5          78          787          10/1/17         True
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price standard_cost  product_first_sold_date
# 0       71.49        $53.62                  41245.0
# 1     2091.47       $388.92                  41701.0
# 2     1793.43       $248.82                  36361.0
# 3     1198.46       $381.10                  36145.0
# 4     1765.30       $709.48                  42226.0

# %%
df["online_order"] = df["online_order"].astype("category").cat.codes

# %%
df["order_status"] = df["order_status"].astype("category").cat.codes

# %%
df["brand"] = df["brand"].astype("category").cat.codes

# %%
df["product_line"] = df["product_line"].astype("category").cat.codes

# %%
df["product_class"] = df["product_class"].astype("category").cat.codes

# %%
df["product_size"] = df["product_size"].astype("category").cat.codes

# %%
df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950          2/25/17             0
# 1                   2           3         3120          5/21/17             1
# 2                   3          37          402         10/16/17             0
# 3                   4          88         3135          8/31/17             0
# 4                   5          78          787          10/1/17             1
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018          6/24/17             1
# 19996           19997          41          127          11/9/17             1
# 19997           19998          87         2284          4/14/17             1
# 19998           19999           6         2764           7/3/17             0
# 19999           20000          11         1144          9/22/17             1
#
#        order_status  brand  product_line  product_class  product_size  \
# 0                 0      3             2              2             1
# 1                 0      4             2              2             0
# 2                 0      2             2              1             1
# 3                 0      1             2              2             1
# 4                 0      0             2              2             0
# ...             ...    ...           ...            ...           ...
# 19995             0      2             2              0             1
# 19996             0      3             1              2             1
# 19997             0      2             2              2             1
# 19998             0      2             2              0             1
# 19999             0      4             2              2             2
#
#        list_price standard_cost  product_first_sold_date
# 0           71.49        $53.62                  41245.0
# 1         2091.47       $388.92                  41701.0
# 2         1793.43       $248.82                  36361.0
# 3         1198.46       $381.10                  36145.0
# 4         1765.30       $709.48                  42226.0
# ...           ...           ...                      ...
# 19995     2005.66     $1,203.40                  37823.0
# 19996      416.98       $312.74                  35560.0
# 19997     1636.90        $44.71                  40410.0
# 19998      227.88       $136.73                  38216.0
# 19999     1775.81     $1,580.47                  36334.0
#
# [19445 rows x 13 columns]

# %%
df.corr()
# Out:
#                          transaction_id  product_id  customer_id  \
# transaction_id                 1.000000   -0.011633     0.002779
# product_id                    -0.011633    1.000000     0.003369
# customer_id                    0.002779    0.003369     1.000000
# online_order                   0.001693   -0.005471     0.003215
# order_status                  -0.010121    0.007236    -0.000821
# brand                          0.010935   -0.001761    -0.006775
# product_line                  -0.001814    0.131254    -0.009402
# product_class                 -0.007154    0.068301    -0.002411
# product_size                  -0.002507   -0.086014    -0.007170
# list_price                    -0.006391    0.090085     0.011671
# product_first_sold_date        0.004391   -0.054155    -0.002306
#
#                          online_order  order_status     brand  product_line  \
# transaction_id               0.001693     -0.010121  0.010935     -0.001814
# product_id                  -0.005471      0.007236 -0.001761      0.131254
# customer_id                  0.003215     -0.000821 -0.006775     -0.009402
# online_order                 1.000000      0.011923 -0.006177     -0.006316
# order_status                 0.011923      1.000000  0.003865     -0.000870
# brand                       -0.006177      0.003865  1.000000      0.119071
# product_line                -0.006316     -0.000870  0.119071      1.000000
# product_class               -0.018633     -0.005970  0.188838      0.060073
# product_size                 0.010397     -0.001013 -0.014845     -0.201128
# list_price                  -0.000927      0.004996  0.078194      0.214501
# product_first_sold_date      0.000902     -0.005966 -0.013414     -0.009233
#
#                          product_class  product_size  list_price  \
# transaction_id               -0.007154     -0.002507   -0.006391
# product_id                    0.068301     -0.086014    0.090085
# customer_id                  -0.002411     -0.007170    0.011671
# online_order                 -0.018633      0.010397   -0.000927
# order_status                 -0.005970     -0.001013    0.004996
# brand                         0.188838     -0.014845    0.078194
# product_line                  0.060073     -0.201128    0.214501
# product_class                 1.000000     -0.097063    0.074661
# product_size                 -0.097063      1.000000   -0.144009
# list_price                    0.074661     -0.144009    1.000000
# product_first_sold_date       0.001593     -0.058988    0.059164
#
#                          product_first_sold_date
# transaction_id                          0.004391
# product_id                             -0.054155
# customer_id                            -0.002306
# online_order                            0.000902
# order_status                           -0.005966
# brand                                  -0.013414
# product_line                           -0.009233
# product_class                           0.001593
# product_size                           -0.058988
# list_price                              0.059164
# product_first_sold_date                 1.000000

# %%
df.cov()
# Out:
#                          transaction_id   product_id   customer_id  \
# transaction_id             3.340457e+07 -2055.547041  1.625202e+04
# product_id                -2.055547e+03   934.646961  1.042161e+02
# customer_id                1.625202e+04   104.216095  1.023920e+06
# online_order               4.892576e+00    -0.083633  1.626686e+00
# order_status              -5.477333e+00     0.020715 -7.778080e-02
# brand                      1.066379e+02    -0.090847 -1.156715e+01
# product_line              -5.892036e+00     2.255433 -5.347286e+00
# product_class             -3.070656e+01     1.550610 -1.811890e+00
# product_size              -8.449044e+00    -1.533580 -4.231008e+00
# list_price                -2.152136e+04  1604.691334  6.880889e+03
# product_first_sold_date    7.304393e+04 -4764.973731 -6.714560e+03
#
#                          online_order  order_status       brand  product_line  \
# transaction_id               4.892576     -5.477333  106.637948     -5.892036
# product_id                  -0.083633      0.020715   -0.090847      2.255433
# customer_id                  1.626686     -0.077781  -11.567146     -5.347286
# online_order                 0.250012      0.000558   -0.005212     -0.001775
# order_status                 0.000558      0.008768    0.000611     -0.000046
# brand                       -0.005212      0.000611    2.847078      0.112927
# product_line                -0.001775     -0.000046    0.112927      0.315927
# product_class               -0.006919     -0.000415    0.236616      0.025074
# product_size                 0.003032     -0.000055   -0.014608     -0.065930
# list_price                  -0.270167      0.272582   76.875722     70.249009
# product_first_sold_date      1.298112     -1.607770  -65.143045    -14.936064
#
#                          product_class  product_size     list_price  \
# transaction_id              -30.706561     -8.449044  -21521.358889
# product_id                    1.550610     -1.533580    1604.691334
# customer_id                  -1.811890     -4.231008    6880.888749
# online_order                 -0.006919      0.003032      -0.270167
# order_status                 -0.000415     -0.000055       0.272582
# brand                         0.236616     -0.014608      76.875722
# product_line                  0.025074     -0.065930      70.249009
# product_class                 0.551452     -0.042036      32.304807
# product_size                 -0.042036      0.340118     -48.935251
# list_price                   32.304807    -48.935251  339495.471923
# product_first_sold_date       3.405252    -99.009658   99214.987844
#
#                          product_first_sold_date
# transaction_id                      7.304393e+04
# product_id                         -4.764974e+03
# customer_id                        -6.714560e+03
# online_order                        1.298112e+00
# order_status                       -1.607770e+00
# brand                              -6.514304e+01
# product_line                       -1.493606e+01
# product_class                       3.405252e+00
# product_size                       -9.900966e+01
# list_price                          9.921499e+04
# product_first_sold_date             8.283275e+06

# %%
import seaborn as sns

# %%
corr = df.corr()
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
sns.heatmap(corr, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
corr
# Out:
#                          transaction_id  product_id  customer_id  \
# transaction_id                 1.000000   -0.011633     0.002779
# product_id                    -0.011633    1.000000     0.003369
# customer_id                    0.002779    0.003369     1.000000
# online_order                   0.001693   -0.005471     0.003215
# order_status                  -0.010121    0.007236    -0.000821
# brand                          0.010935   -0.001761    -0.006775
# product_line                  -0.001814    0.131254    -0.009402
# product_class                 -0.007154    0.068301    -0.002411
# product_size                  -0.002507   -0.086014    -0.007170
# list_price                    -0.006391    0.090085     0.011671
# product_first_sold_date        0.004391   -0.054155    -0.002306
#
#                          online_order  order_status     brand  product_line  \
# transaction_id               0.001693     -0.010121  0.010935     -0.001814
# product_id                  -0.005471      0.007236 -0.001761      0.131254
# customer_id                  0.003215     -0.000821 -0.006775     -0.009402
# online_order                 1.000000      0.011923 -0.006177     -0.006316
# order_status                 0.011923      1.000000  0.003865     -0.000870
# brand                       -0.006177      0.003865  1.000000      0.119071
# product_line                -0.006316     -0.000870  0.119071      1.000000
# product_class               -0.018633     -0.005970  0.188838      0.060073
# product_size                 0.010397     -0.001013 -0.014845     -0.201128
# list_price                  -0.000927      0.004996  0.078194      0.214501
# product_first_sold_date      0.000902     -0.005966 -0.013414     -0.009233
#
#                          product_class  product_size  list_price  \
# transaction_id               -0.007154     -0.002507   -0.006391
# product_id                    0.068301     -0.086014    0.090085
# customer_id                  -0.002411     -0.007170    0.011671
# online_order                 -0.018633      0.010397   -0.000927
# order_status                 -0.005970     -0.001013    0.004996
# brand                         0.188838     -0.014845    0.078194
# product_line                  0.060073     -0.201128    0.214501
# product_class                 1.000000     -0.097063    0.074661
# product_size                 -0.097063      1.000000   -0.144009
# list_price                    0.074661     -0.144009    1.000000
# product_first_sold_date       0.001593     -0.058988    0.059164
#
#                          product_first_sold_date
# transaction_id                          0.004391
# product_id                             -0.054155
# customer_id                            -0.002306
# online_order                            0.000902
# order_status                           -0.005966
# brand                                  -0.013414
# product_line                           -0.009233
# product_class                           0.001593
# product_size                           -0.058988
# list_price                              0.059164
# product_first_sold_date                 1.000000

# %%
dates =df['transaction_date']

# %%
dates
# Out:
# 0         2/25/17
# 1         5/21/17
# 2        10/16/17
# 3         8/31/17
# 4         10/1/17
#            ...
# 19995     6/24/17
# 19996     11/9/17
# 19997     4/14/17
# 19998      7/3/17
# 19999     9/22/17
# Name: transaction_date, Length: 19445, dtype: object

# %%
# add 
# dayof week
# month
# day

# %%
no_year = []

for i in dates:
    no_year.append(i[:-3])

# %%
df['dates'] = no_year

# %%
df1 = df.copy()

# %%
df1 = df1.drop(columns=['transaction_date'])

# %%
date = df1['dates']

# %%
days = []
months = []

for i in date:
    if (i[1] == '/'):
        months.append(i[0])
        days.append(i[2:])
    else:
        months.append(i[0:2])
        days.append(i[3:])

# %%
days
# Out:
# ['25',
#  '21',
#  '16',
#  '31',
#  '1',
#  '8',
#  '21',
#  '15',
#  '10',
#  '30',
#  '17',
#  '5',
#  '26',
#  '10',
#  '11',
#  '10',
#  '3',
#  '2',
#  '6',
#  '28',
#  '9',
#  '29',
#  '8',
#  '18',
#  '11',
#  '10',
#  '11',
#  '23',
#  '13',
#  '15',
#  '5',
#  '18',
#  '20',
#  '28',
#  '20',
#  '7',
#  '9',
#  '6',
#  '12',
#  '28',
#  '8',
#  '14',
#  '17',
#  '22',
#  '7',
#  '20',
#  '7',
#  '10',
#  '17',
#  '10',
#  '24',
#  '27',
#  '21',
#  '9',
#  '18',
#  '14',
#  '30',
#  '14',
#  '15',
#  '18',
#  '24',
#  '18',
#  '17',
#  '8',
#  '16',
#  '23',
#  '3',
#  '30',
#  '21',
#  '6',
#  '3',
#  '9',
#  '23',
#  '21',
#  '20',
#  '10',
#  '2',
#  '7',
#  '12',
#  '16',
#  '7',
#  '27',
#  '1',
#  '2',
#  '13',
#  '19',
#  '23',
#  '6',
#  '4',
#  '15',
#  '15',
#  '25',
#  '28',
#  '23',
#  '26',
#  '21',
#  '31',
#  '26',
#  '31',
#  '27',
#  '14',
#  '12',
#  '12',
#  '26',
#  '15',
#  '22',
#  '11',
#  '27',
#  '4',
#  '11',
#  '9',
#  '7',
#  '24',
#  '1',
#  '21',
#  '24',
#  '21',
#  '20',
#  '16',
#  '4',
#  '1',
#  '5',
#  '21',
#  '3',
#  '1',
#  '16',
#  '26',
#  '5',
#  '4',
#  '18',
#  '28',
#  '2',
#  '9',
#  '17',
#  '25',
#  '2',
#  '25',
#  '1',
#  '22',
#  '25',
#  '26',
#  '20',
#  '7',
#  '6',
#  '25',
#  '13',
#  '21',
#  '21',
#  '11',
#  '16',
#  '19',
#  '6',
#  '4',
#  '22',
#  '15',
#  '1',
#  '16',
#  '10',
#  '11',
#  '20',
#  '30',
#  '25',
#  '27',
#  '2',
#  '2',
#  '22',
#  '11',
#  '16',
#  '17',
#  '23',
#  '30',
#  '13',
#  '25',
#  '31',
#  '18',
#  '24',
#  '18',
#  '7',
#  '5',
#  '19',
#  '8',
#  '24',
#  '15',
#  '12',
#  '27',
#  '30',
#  '15',
#  '22',
#  '2',
#  '27',
#  '21',
#  '23',
#  '2',
#  '8',
#  '15',
#  '5',
#  '26',
#  '29',
#  '3',
#  '27',
#  '5',
#  '9',
#  '21',
#  '22',
#  '12',
#  '7',
#  '13',
#  '14',
#  '22',
#  '30',
#  '29',
#  '9',
#  '21',
#  '13',
#  '9',
#  '8',
#  '8',
#  '30',
#  '25',
#  '30',
#  '10',
#  '16',
#  '4',
#  '13',
#  '23',
#  '12',
#  '4',
#  '1',
#  '1',
#  '2',
#  '31',
#  '11',
#  '8',
#  '1',
#  '23',
#  '27',
#  '4',
#  '13',
#  '20',
#  '22',
#  '22',
#  '29',
#  '21',
#  '10',
#  '25',
#  '3',
#  '30',
#  '26',
#  '1',
#  '22',
#  '22',
#  '15',
#  '6',
#  '28',
#  '9',
#  '18',
#  '22',
#  '30',
#  '26',
#  '7',
#  '13',
#  '27',
#  '25',
#  '13',
#  '11',
#  '30',
#  '19',
#  '26',
#  '3',
#  '28',
#  '23',
#  '3',
#  '25',
#  '8',
#  '18',
#  '4',
#  '29',
#  '3',
#  '27',
#  '7',
#  '7',
#  '20',
#  '23',
#  '5',
#  '7',
#  '28',
#  '19',
#  '25',
#  '20',
#  '14',
#  '14',
#  '20',
#  '24',
#  '25',
#  '17',
#  '18',
#  '7',
#  '4',
#  '13',
#  '20',
#  '21',
#  '27',
#  '21',
#  '7',
#  '4',
#  '25',
#  '20',
#  '18',
#  '1',
#  '19',
#  '31',
#  '9',
#  '20',
#  '23',
#  '19',
#  '8',
#  '11',
#  '14',
#  '20',
#  '9',
#  '17',
#  '11',
#  '15',
#  '23',
#  '2',
#  '16',
#  '21',
#  '1',
#  '5',
#  '2',
#  '4',
#  '16',
#  '27',
#  '14',
#  '9',
#  '21',
#  '19',
#  '12',
#  '11',
#  '20',
#  '26',
#  '15',
#  '19',
#  '20',
#  '14',
#  '22',
#  '9',
#  '13',
#  '6',
#  '10',
#  '26',
#  '31',
#  '22',
#  '14',
#  '13',
#  '3',
#  '22',
#  '24',
#  '29',
#  '3',
#  '28',
#  '16',
#  '24',
#  '7',
#  '5',
#  '9',
#  '17',
#  '27',
#  '3',
#  '20',
#  '18',
#  '2',
#  '28',
#  '28',
#  '14',
#  '1',
#  '15',
#  '3',
#  '15',
#  '4',
#  '12',
#  '19',
#  '30',
#  '29',
#  '12',
#  '27',
#  '27',
#  '12',
#  '24',
#  '5',
#  '14',
#  '17',
#  '14',
#  '19',
#  '17',
#  '11',
#  '8',
#  '7',
#  '30',
#  '11',
#  '9',
#  '2',
#  '1',
#  '3',
#  '2',
#  '10',
#  '19',
#  '25',
#  '28',
#  '26',
#  '15',
#  '3',
#  '6',
#  '24',
#  '19',
#  '30',
#  '15',
#  '26',
#  '12',
#  '19',
#  '17',
#  '10',
#  '22',
#  '26',
#  '27',
#  '17',
#  '5',
#  '20',
#  '25',
#  '24',
#  '25',
#  '10',
#  '25',
#  '23',
#  '23',
#  '28',
#  '31',
#  '1',
#  '2',
#  '20',
#  '22',
#  '3',
#  '16',
#  '30',
#  '10',
#  '25',
#  '29',
#  '7',
#  '9',
#  '5',
#  '14',
#  '13',
#  '17',
#  '24',
#  '15',
#  '2',
#  '11',
#  '30',
#  '21',
#  '9',
#  '11',
#  '7',
#  '10',
#  '19',
#  '18',
#  '8',
#  '17',
#  '15',
#  '22',
#  '15',
#  '4',
#  '17',
#  '24',
#  '15',
#  '9',
#  '25',
#  '12',
#  '10',
#  '11',
#  '3',
#  '16',
#  '9',
#  '8',
#  '30',
#  '29',
#  '19',
#  '2',
#  '25',
#  '13',
#  '7',
#  '10',
#  '9',
#  '4',
#  '2',
#  '24',
#  '28',
#  '23',
#  '4',
#  '2',
#  '29',
#  '2',
#  '18',
#  '3',
#  '1',
#  '25',
#  '19',
#  '21',
#  '18',
#  '26',
#  '7',
#  '10',
#  '27',
#  '2',
#  '27',
#  '4',
#  '3',
#  '10',
#  '15',
#  '9',
#  '8',
#  '28',
#  '3',
#  '18',
#  '23',
#  '4',
#  '2',
#  '13',
#  '8',
#  '3',
#  '19',
#  '19',
#  '21',
#  '26',
#  '6',
#  '25',
#  '5',
#  '15',
#  '30',
#  '22',
#  '31',
#  '8',
#  '4',
#  '16',
#  '22',
#  '10',
#  '1',
#  '23',
#  '5',
#  '18',
#  '23',
#  '28',
#  '9',
#  '4',
#  '8',
#  '21',
#  '20',
#  '27',
#  '6',
#  '25',
#  '26',
#  '26',
#  '13',
#  '31',
#  '13',
#  '19',
#  '3',
#  '16',
#  '13',
#  '22',
#  '14',
#  '14',
#  '30',
#  '4',
#  '16',
#  '23',
#  '21',
#  '14',
#  '17',
#  '12',
#  '1',
#  '13',
#  '3',
#  '8',
#  '24',
#  '27',
#  '23',
#  '12',
#  '4',
#  '23',
#  '30',
#  '28',
#  '14',
#  '29',
#  '20',
#  '6',
#  '20',
#  '3',
#  '8',
#  '22',
#  '13',
#  '12',
#  '27',
#  '16',
#  '22',
#  '27',
#  '14',
#  '1',
#  '12',
#  '15',
#  '12',
#  '20',
#  '17',
#  '11',
#  '10',
#  '20',
#  '10',
#  '10',
#  '29',
#  '31',
#  '2',
#  '14',
#  '11',
#  '17',
#  '5',
#  '19',
#  '5',
#  '28',
#  '20',
#  '27',
#  '12',
#  '5',
#  '16',
#  '1',
#  '26',
#  '11',
#  '23',
#  '28',
#  '17',
#  '12',
#  '28',
#  '21',
#  '4',
#  '18',
#  '17',
#  '16',
#  '26',
#  '15',
#  '21',
#  '9',
#  '16',
#  '14',
#  '3',
#  '7',
#  '29',
#  '9',
#  '22',
#  '8',
#  '2',
#  '5',
#  '26',
#  '6',
#  '20',
#  '31',
#  '5',
#  '23',
#  '10',
#  '19',
#  '20',
#  '19',
#  '16',
#  '1',
#  '13',
#  '18',
#  '21',
#  '11',
#  '24',
#  '15',
#  '22',
#  '6',
#  '21',
#  '2',
#  '13',
#  '2',
#  '20',
#  '5',
#  '2',
#  '1',
#  '26',
#  '5',
#  '18',
#  '2',
#  '15',
#  '29',
#  '5',
#  '18',
#  '6',
#  '20',
#  '29',
#  '8',
#  '23',
#  '16',
#  '3',
#  '16',
#  '19',
#  '4',
#  '28',
#  '29',
#  '13',
#  '25',
#  '9',
#  '9',
#  '15',
#  '9',
#  '9',
#  '8',
#  '12',
#  '30',
#  '18',
#  '30',
#  '10',
#  '21',
#  '16',
#  '6',
#  '2',
#  '9',
#  '22',
#  '20',
#  '3',
#  '31',
#  '21',
#  '30',
#  '17',
#  '28',
#  '10',
#  '29',
#  '7',
#  '2',
#  '11',
#  '14',
#  '25',
#  '9',
#  '5',
#  '22',
#  '27',
#  '10',
#  '28',
#  '13',
#  '26',
#  '6',
#  '15',
#  '9',
#  '13',
#  '10',
#  '26',
#  '6',
#  '4',
#  '16',
#  '4',
#  '5',
#  '15',
#  '1',
#  '12',
#  '7',
#  '5',
#  '3',
#  '14',
#  '25',
#  '28',
#  '3',
#  '29',
#  '18',
#  '15',
#  '27',
#  '20',
#  '5',
#  '15',
#  '8',
#  '6',
#  '4',
#  '3',
#  '9',
#  '28',
#  '12',
#  '21',
#  '22',
#  '21',
#  '17',
#  '10',
#  '27',
#  '16',
#  '10',
#  '13',
#  '26',
#  '24',
#  '19',
#  '8',
#  '7',
#  '22',
#  '12',
#  '8',
#  '24',
#  '11',
#  '7',
#  '20',
#  '3',
#  '20',
#  '3',
#  '10',
#  '4',
#  '8',
#  '25',
#  '30',
#  '14',
#  '23',
#  '17',
#  '16',
#  '11',
#  '20',
#  '3',
#  '7',
#  '16',
#  '6',
#  '11',
#  '14',
#  '26',
#  '28',
#  '28',
#  '18',
#  '8',
#  '12',
#  '28',
#  '21',
#  '25',
#  '15',
#  '12',
#  '10',
#  '8',
#  '13',
#  '22',
#  '10',
#  '21',
#  '7',
#  '3',
#  '23',
#  '13',
#  '14',
#  '15',
#  '23',
#  '19',
#  '22',
#  '24',
#  '17',
#  '25',
#  '21',
#  '2',
#  '13',
#  '6',
#  '9',
#  '18',
#  '20',
#  '11',
#  '9',
#  '13',
#  '23',
#  '24',
#  '14',
#  '10',
#  '14',
#  '1',
#  '9',
#  '23',
#  '17',
#  '29',
#  '16',
#  '4',
#  '2',
#  '3',
#  '30',
#  '9',
#  '9',
#  '21',
#  '10',
#  '2',
#  '12',
#  '26',
#  '16',
#  '17',
#  '20',
#  '11',
#  '11',
#  '19',
#  '26',
#  '29',
#  '27',
#  '15',
#  '18',
#  '26',
#  '19',
#  '4',
#  '4',
#  '19',
#  '14',
#  '17',
#  '29',
#  '4',
#  '7',
#  '4',
#  '27',
#  '4',
#  '17',
#  '10',
#  '5',
#  '9',
#  '19',
#  '11',
#  '19',
#  '13',
#  '12',
#  '18',
#  '8',
#  '31',
#  '13',
#  '15',
#  '12',
#  '9',
#  '23',
#  '16',
#  '17',
#  '15',
#  '23',
#  '9',
#  '3',
#  '18',
#  '14',
#  '13',
#  '15',
#  '18',
#  '27',
#  '25',
#  '30',
#  '14',
#  '13',
#  '30',
#  '26',
#  '28',
#  '20',
#  '11',
#  '26',
#  '17',
#  '1',
#  '1',
#  '23',
#  '10',
#  '14',
#  '11',
#  '21',
#  '22',
#  '23',
#  '13',
#  '29',
#  '11',
#  '17',
#  '28',
#  '27',
#  '24',
#  '8',
#  '31',
#  '2',
#  '25',
#  '23',
#  '13',
#  '5',
#  '16',
#  '19',
#  '3',
#  '18',
#  '15',
#  '6',
#  '14',
#  '31',
#  '10',
#  '29',
#  '4',
#  '12',
#  '24',
#  '23',
#  '5',
#  '29',
#  '29',
#  '27',
#  '29',
#  '17',
#  '16',
#  '13',
#  '4',
#  '28',
#  '26',
#  '8',
#  '4',
#  '12',
#  ...]

# %%
df1['days'] = days
df1['months'] = months

# %%
df1
# Out:
#        transaction_id  product_id  customer_id  online_order  order_status  \
# 0                   1           2         2950             0             0
# 1                   2           3         3120             1             0
# 2                   3          37          402             0             0
# 3                   4          88         3135             0             0
# 4                   5          78          787             1             0
# ...               ...         ...          ...           ...           ...
# 19995           19996          51         1018             1             0
# 19996           19997          41          127             1             0
# 19997           19998          87         2284             1             0
# 19998           19999           6         2764             0             0
# 19999           20000          11         1144             1             0
#
#        brand  product_line  product_class  product_size  list_price  \
# 0          3             2              2             1       71.49
# 1          4             2              2             0     2091.47
# 2          2             2              1             1     1793.43
# 3          1             2              2             1     1198.46
# 4          0             2              2             0     1765.30
# ...      ...           ...            ...           ...         ...
# 19995      2             2              0             1     2005.66
# 19996      3             1              2             1      416.98
# 19997      2             2              2             1     1636.90
# 19998      2             2              0             1      227.88
# 19999      4             2              2             2     1775.81
#
#       standard_cost  product_first_sold_date  dates days months
# 0            $53.62                  41245.0   2/25   25      2
# 1           $388.92                  41701.0   5/21   21      5
# 2           $248.82                  36361.0  10/16   16     10
# 3           $381.10                  36145.0   8/31   31      8
# 4           $709.48                  42226.0   10/1    1     10
# ...             ...                      ...    ...  ...    ...
# 19995     $1,203.40                  37823.0   6/24   24      6
# 19996       $312.74                  35560.0   11/9    9     11
# 19997        $44.71                  40410.0   4/14   14      4
# 19998       $136.73                  38216.0    7/3    3      7
# 19999     $1,580.47                  36334.0   9/22   22      9
#
# [19445 rows x 15 columns]

# %%
df1 = df1.drop(columns=['dates'])

# %%
df1
# Out:
#        transaction_id  product_id  customer_id  online_order  order_status  \
# 0                   1           2         2950             0             0
# 1                   2           3         3120             1             0
# 2                   3          37          402             0             0
# 3                   4          88         3135             0             0
# 4                   5          78          787             1             0
# ...               ...         ...          ...           ...           ...
# 19995           19996          51         1018             1             0
# 19996           19997          41          127             1             0
# 19997           19998          87         2284             1             0
# 19998           19999           6         2764             0             0
# 19999           20000          11         1144             1             0
#
#        brand  product_line  product_class  product_size  list_price  \
# 0          3             2              2             1       71.49
# 1          4             2              2             0     2091.47
# 2          2             2              1             1     1793.43
# 3          1             2              2             1     1198.46
# 4          0             2              2             0     1765.30
# ...      ...           ...            ...           ...         ...
# 19995      2             2              0             1     2005.66
# 19996      3             1              2             1      416.98
# 19997      2             2              2             1     1636.90
# 19998      2             2              0             1      227.88
# 19999      4             2              2             2     1775.81
#
#       standard_cost  product_first_sold_date days months
# 0            $53.62                  41245.0   25      2
# 1           $388.92                  41701.0   21      5
# 2           $248.82                  36361.0   16     10
# 3           $381.10                  36145.0   31      8
# 4           $709.48                  42226.0    1     10
# ...             ...                      ...  ...    ...
# 19995     $1,203.40                  37823.0   24      6
# 19996       $312.74                  35560.0    9     11
# 19997        $44.71                  40410.0   14      4
# 19998       $136.73                  38216.0    3      7
# 19999     $1,580.47                  36334.0   22      9
#
# [19445 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19445 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           19445 non-null  int64
#  1   product_id               19445 non-null  int64
#  2   customer_id              19445 non-null  int64
#  3   transaction_date         19445 non-null  object
#  4   online_order             19445 non-null  int8
#  5   order_status             19445 non-null  int8
#  6   brand                    19445 non-null  int8
#  7   product_line             19445 non-null  int8
#  8   product_class            19445 non-null  int8
#  9   product_size             19445 non-null  int8
#  10  list_price               19445 non-null  float64
#  11  standard_cost            19445 non-null  object
#  12  product_first_sold_date  19445 non-null  float64
#  13  dates                    19445 non-null  object
#  14  days                     19445 non-null  object
#  15  months                   19445 non-null  object
# dtypes: float64(2), int64(3), int8(6), object(5)
# memory usage: 1.7+ MB

# %%
df1['days'] = df1['days'].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19445 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           19445 non-null  int64
#  1   product_id               19445 non-null  int64
#  2   customer_id              19445 non-null  int64
#  3   online_order             19445 non-null  int8
#  4   order_status             19445 non-null  int8
#  5   brand                    19445 non-null  int8
#  6   product_line             19445 non-null  int8
#  7   product_class            19445 non-null  int8
#  8   product_size             19445 non-null  int8
#  9   list_price               19445 non-null  float64
#  10  standard_cost            19445 non-null  object
#  11  product_first_sold_date  19445 non-null  float64
#  12  days                     19445 non-null  int64
#  13  months                   19445 non-null  object
# dtypes: float64(2), int64(4), int8(6), object(2)
# memory usage: 1.4+ MB

# %%
df1['months'] = df1['months'].astype(int)

# %%
cost = df1['standard_cost']

# %%
costs = []

for i in cost:
    costs.append(i[1:])

# %%
df1['cost'] = costs

# %%
df1 = df1.drop(columns=['standard_cost'])

# %%
df1
# Out:
#        transaction_id  product_id  customer_id  online_order  order_status  \
# 0                   1           2         2950             0             0
# 1                   2           3         3120             1             0
# 2                   3          37          402             0             0
# 3                   4          88         3135             0             0
# 4                   5          78          787             1             0
# ...               ...         ...          ...           ...           ...
# 19995           19996          51         1018             1             0
# 19996           19997          41          127             1             0
# 19997           19998          87         2284             1             0
# 19998           19999           6         2764             0             0
# 19999           20000          11         1144             1             0
#
#        brand  product_line  product_class  product_size  list_price  \
# 0          3             2              2             1       71.49
# 1          4             2              2             0     2091.47
# 2          2             2              1             1     1793.43
# 3          1             2              2             1     1198.46
# 4          0             2              2             0     1765.30
# ...      ...           ...            ...           ...         ...
# 19995      2             2              0             1     2005.66
# 19996      3             1              2             1      416.98
# 19997      2             2              2             1     1636.90
# 19998      2             2              0             1      227.88
# 19999      4             2              2             2     1775.81
#
#        product_first_sold_date  days  months      cost
# 0                      41245.0    25       2     53.62
# 1                      41701.0    21       5    388.92
# 2                      36361.0    16      10    248.82
# 3                      36145.0    31       8    381.10
# 4                      42226.0     1      10    709.48
# ...                        ...   ...     ...       ...
# 19995                  37823.0    24       6  1,203.40
# 19996                  35560.0     9      11    312.74
# 19997                  40410.0    14       4     44.71
# 19998                  38216.0     3       7    136.73
# 19999                  36334.0    22       9  1,580.47
#
# [19445 rows x 14 columns]

# %%
corr = df1.corr()
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %%
corr = df1.corr()
sns.heatmap(corr, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
df1.size
# Out:
# 272230

# %%
df1 = df1.drop_duplicates()

# %%
df1.size
# Out:
# 272230
